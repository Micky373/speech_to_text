# %%
import numpy as np
from scipy.io import wavfile #for audio processing
import warnings
import sys, os
warnings.filterwarnings("ignore")
import librosa   
import IPython.display as ipd
import matplotlib.pyplot as plt

# %% [markdown]
# Ingnore Warning

# %%
warnings.filterwarnings('ignore')

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))

from data_argumentation import *

# %%
train_audio_path = '../data/'
samples, sample_rate = librosa.load(train_audio_path+'tr_10_tr01010.wav')
print(samples)
print(sample_rate)
# Out:
# [-0.00562254 -0.00654164 -0.00564277 ... -0.00509709 -0.00456561
#   0.        ]
# 22050

# %% [markdown]
# It returns numpy arrays of 22KHZ

# %%
audio, rate=librosa.load(train_audio_path+'tr_10_tr01010.wav', sr=44100)

# %% [markdown]
# ### Lisitening the Audio

# %%
ipd.Audio(samples, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Visualizing Audio

# %%
# %matplotlib inline
import librosa.display
#Plot the signal:
plt.figure(figsize=(20, 5))
librosa.display.waveshow(samples, sr=sample_rate)

# %% [markdown]
# ## Time Shifting

# %% [markdown]
# moving the wave to the right by shifting the sample_rate/10 along the time axis. Using the numpy rolls function to achieve this.

# %%
wav_roll = time_shift(samples,int(sample_rate/10))
plot_spec(data=wav_roll,sr=sample_rate)

# %% [markdown]
# ## Mel-Frequency Cepstral Coefficients(MFCCs)

# %%
# MFCC
plt.figure(figsize=(20,5))
mfccs = librosa.feature.mfcc(samples, sr=sample_rate)
print(mfccs.shape)

librosa.display.specshow(mfccs, sr=sample_rate, x_axis='time')
# Out:
# (20, 447)
